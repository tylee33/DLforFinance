# %% [markdown]
# <a href="https://colab.research.google.com/github/tylee33/DLforFinance/blob/master/Stocker_Prediction_Usage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Matplotlib for plotting in the notebook
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from stocker import Stocker

# %%
amazon = Stocker('AMZN')
# Out:
# AMZN Stocker Initialized. Data covers 1997-05-16 00:00:00 to 2018-03-27 00:00:00.

# %% [markdown]
# **Basic Plot of Stock History**

# %%
amazon.plot_stock()
# Out:
# Maximum Adj. Close = 1598.39 on 2018-03-12 00:00:00.
# Minimum Adj. Close = 1.40 on 1997-05-22 00:00:00.
# Current Adj. Close = 1497.05 on 2018-03-27 00:00:00.
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Plot of Daily Changes**

# %%
amazon.plot_stock(stats=['Daily Change'])
# Out:
# Maximum Daily Change = 81.38 on 2018-02-06 00:00:00.
# Minimum Daily Change = -79.20 on 2018-02-08 00:00:00.
# Current Daily Change = -75.35 on 2018-03-27 00:00:00.

# %% [markdown]
# **Examine Trends/Patterns**

# %%
model, model_data = amazon.create_prophet_model()
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()

# %%
# Variables assigned from previous method call
model.plot_components(model_data)
plt.show()

# %% [markdown]
# **Test Addition of a Weekly Seasonality**

# %%
amazon.weekly_seasonality=True
model, model_data = amazon.create_prophet_model()
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()

# %%
model.plot_components(model_data)
plt.show()

# %%
amazon.weekly_seasonality=False

# %% [markdown]
# # **First Predictions**

# %%
model, model_data = amazon.create_prophet_model(days=90)
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# Predicted Price on 2018-06-25 00:00:00 = $1882.69

# %% [markdown]
# # **Evaluate Model**

# %%
amazon.evaluate_prediction()
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $1063.08.
# Actual price on    2018-03-23 00:00:00 = $1495.56.
#
# Average Absolute Error on Training Data = $16.27.
# Average Absolute Error on Testing  Data = $135.92.
#
# When the model predicted an increase, the price increased 57.76% of the time.
# When the model predicted a  decrease, the price decreased  42.53% of the time.
#
# The actual value was within the 80% confidence interval 64.66% of the time.

# %% [markdown]
# # **Changepoint Prior Scale Selection**

# %% [markdown]
# **Graphical Comparison**

# %%
amazon.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()

# %% [markdown]
# **Quantitative Comparison**

# %%
amazon.changepoint_prior_validation(start_date='2016-01-04', end_date='2017-01-03', changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# Validation Range 2016-01-04 00:00:00 to 2017-01-03 00:00:00.
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
#      cps  train_err  train_range    test_err  test_range
# 0  0.001  44.476286   152.718210  149.378762  152.886651
# 1  0.050  11.225187    35.906388  148.769640  138.931578
# 2  0.100  10.710383    34.577274  149.751968  171.108532
# 3  0.200   9.810689    32.128157  126.039086  330.791521

# %% [markdown]
# **Refine Search**

# %%
amazon.changepoint_prior_validation(start_date='2016-01-04', end_date='2017-01-03', changepoint_priors=[0.15, 0.2, 0.25,0.4, 0.5, 0.6])
# Out:
# Validation Range 2016-01-04 00:00:00 to 2017-01-03 00:00:00.
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
#     cps  train_err  train_range    test_err  test_range
# 0  0.15  10.349379    33.561387  146.166050  219.523562
# 1  0.20   9.810689    32.169765  126.039086  325.538746
# 2  0.25   9.378231    30.958737  110.433461  431.268183
# 3  0.40   8.569736    28.856337   72.118846  785.167982
# 4  0.50   8.359124    28.305522   74.421845  888.897752
# 5  0.60   8.267228    28.084771   77.989126  888.719052

# %%
amazon.changepoint_prior_scale = 0.5

# %% [markdown]
# **Evaluate Improved Model**

# %%
amazon.evaluate_prediction()
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $1002.10.
# Actual price on    2018-03-23 00:00:00 = $1495.56.
#
# Average Absolute Error on Training Data = $10.89.
# Average Absolute Error on Testing  Data = $175.86.
#
# When the model predicted an increase, the price increased 59.73% of the time.
# When the model predicted a  decrease, the price decreased  45.45% of the time.
#
# The actual value was within the 80% confidence interval 83.94% of the time.

# %% [markdown]
# **Add in weekly seasonality and evaluate**

# %%
amazon.weekly_seasonality=True

# %%
amazon.evaluate_prediction()
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# Prediction Range: 2017-03-27 00:00:00 to 2018-03-27 00:00:00.
#
# Predicted price on 2018-03-24 00:00:00 = $973.95.
# Actual price on    2018-03-23 00:00:00 = $1495.56.
#
# Average Absolute Error on Training Data = $10.83.
# Average Absolute Error on Testing  Data = $180.52.
#
# When the model predicted an increase, the price increased 61.33% of the time.
# When the model predicted a  decrease, the price decreased  47.96% of the time.
#
# The actual value was within the 80% confidence interval 89.16% of the time.

# %%
amazon.changepoint_prior_scale=0.5
amazon.weekly_seasonality=True

# %% [markdown]
# # Play the Daily Market

# %%
amazon.evaluate_prediction(nshares=1000)
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /content/stocker.py:613: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_pred_increase['pred_profit'] = prediction_profit
# You played the stock market in AMZN from 2017-03-27 00:00:00 to 2018-03-27 00:00:00 with 1000 shares.
#
# When the model predicted an increase, the price increased 61.33% of the time.
# When the model predicted a  decrease, the price decreased  47.96% of the time.
#
# The total profit using the Prophet model = $564950.00.
# The Buy and Hold strategy profit =         $648740.00.
#
# Thanks for playing the stock market!

# %% [markdown]
# **Try a Different Period**

# %%
amazon.evaluate_prediction(start_date = '2008-01-03', end_date = '2009-01-05', nshares=1000)
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# /content/stocker.py:613: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   test_pred_increase['pred_profit'] = prediction_profit
# You played the stock market in AMZN from 2008-01-03 00:00:00 to 2009-01-05 00:00:00 with 1000 shares.
#
# When the model predicted an increase, the price increased 42.69% of the time.
# When the model predicted a  decrease, the price decreased  53.75% of the time.
#
# The total profit using the Prophet model = $-42230.00.
# The Buy and Hold strategy profit =         $-43930.00.
#
# Thanks for playing the stock market!

# %% [markdown]
# # **Predict the Future**

# %%
amazon.predict_future(days=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# Predicted Increase:
#
#          Date     estimate     change        upper        lower
# 1  2018-03-28  1577.180099   2.994918  1598.581516  1555.194815
# 2  2018-03-29  1579.809845   2.629746  1600.551258  1556.965625
# 3  2018-03-30  1586.577626   6.767781  1609.068681  1566.534064
# 5  2018-04-01  1627.850670  41.273044  1649.096684  1606.546454
# 8  2018-04-04  1602.921998   1.159360  1624.769196  1580.964650
# 9  2018-04-05  1605.569502   2.647505  1628.473998  1584.561022
# 10 2018-04-06  1612.697836   7.128334  1635.434735  1590.052844
#
# Predicted Decrease:
#
#         Date     estimate     change        upper        lower
# 6 2018-04-02  1601.864016 -25.986654  1624.709695  1581.242956
# 7 2018-04-03  1601.762638  -0.101379  1625.038387  1579.828695

# %%
amazon.predict_future(days=100)
# Out:
# /usr/local/lib/python3.6/dist-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# Predicted