# %%
from fredapi import Fred
fred = Fred(api_key='9b0bdf64ed44e1781f17d4fb434ff48e')

# %%
import pandas
fred.search_by_category(106, limit=5, order_by="popularity")
# Out:
#                  frequency frequency_short               id  \
# series id
# C362RX1A020NBEA     Annual               A  C362RX1A020NBEA
# C027RX1A020NBEA     Annual               A  C027RX1A020NBEA
# W489RS2A224NBEA     Annual               A  W489RS2A224NBEA
# B981RS2Q224SBEA  Quarterly               Q  B981RS2Q224SBEA
# Y695RY2Q224SBEA  Quarterly               Q  Y695RY2Q224SBEA
#
#                        last_updated  \
# series id
# C362RX1A020NBEA 2018-03-28 12:54:43
# C027RX1A020NBEA 2018-03-28 12:54:44
# W489RS2A224NBEA 2018-01-26 14:28:51
# B981RS2Q224SBEA 2018-04-27 12:54:38
# Y695RY2Q224SBEA 2018-04-27 12:53:24
#
#                                                              notes  \
# series id
# C362RX1A020NBEA  BEA Account Code: C362RX  For more information...
# C027RX1A020NBEA  BEA Account Code: C027RX  For more information...
# W489RS2A224NBEA  BEA Account Code: W489RS  For more information...
# B981RS2Q224SBEA  BEA Account Code: B981RS  For more information...
# Y695RY2Q224SBEA  BEA Account Code: Y695RY  For more information...
#
#                 observation_end observation_start popularity realtime_end  \
# series id
# C362RX1A020NBEA      2017-01-01        1929-01-01          0   2018-05-24
# C027RX1A020NBEA      2017-01-01        1929-01-01          0   2018-05-24
# W489RS2A224NBEA      2017-01-01        1979-01-01          0   2018-05-24
# B981RS2Q224SBEA      2018-01-01        1982-04-01          0   2018-05-24
# Y695RY2Q224SBEA      2018-01-01        1947-04-01          0   2018-05-24
#
#                 realtime_start              seasonal_adjustment  \
# series id
# C362RX1A020NBEA     2018-05-24          Not Seasonally Adjusted
# C027RX1A020NBEA     2018-05-24          Not Seasonally Adjusted
# W489RS2A224NBEA     2018-05-24          Not Seasonally Adjusted
# B981RS2Q224SBEA     2018-05-24  Seasonally Adjusted Annual Rate
# Y695RY2Q224SBEA     2018-05-24  Seasonally Adjusted Annual Rate
#
#                 seasonal_adjustment_short  \
# series id
# C362RX1A020NBEA                       NSA
# C027RX1A020NBEA                       NSA
# W489RS2A224NBEA                       NSA
# B981RS2Q224SBEA                      SAAR
# Y695RY2Q224SBEA                      SAAR
#
#                                                              title  \
# series id
# C362RX1A020NBEA            Command-basis real net domestic product
# C027RX1A020NBEA            Command-basis real net national product
# W489RS2A224NBEA  Contributions to percent change in gross domes...
# B981RS2Q224SBEA  Contributions to percent change in gross domes...
# Y695RY2Q224SBEA  Contributions to Percent Change in Real Gross ...
#
#                                             units  \
# series id
# C362RX1A020NBEA  Billions of Chained 2009 Dollars
# C027RX1A020NBEA  Billions of Chained 2009 Dollars
# W489RS2A224NBEA  Percentage Points at Annual Rate
# B981RS2Q224SBEA  Percentage Points at Annual Rate
# Y695RY2Q224SBEA  Percentage Points at Annual Rate
#
#                                       units_short
# series id
# C362RX1A020NBEA               Bil. of Chn. 2009 $
# C027RX1A020NBEA               Bil. of Chn. 2009 $
# W489RS2A224NBEA  Percentage Points at Annual Rate
# B981RS2Q224SBEA  Percentage Points at Annual Rate
# Y695RY2Q224SBEA  Percentage Points at Annual Rate

# %%
fred.search_by_release(53, limit=5, order_by="popularity")
# Out:
#                  frequency frequency_short               id  \
# series id
# A138RG3A086NBEA     Annual               A  A138RG3A086NBEA
# A138RC1A027NBEA     Annual               A  A138RC1A027NBEA
# B139RG3Q086SBEA  Quarterly               Q  B139RG3Q086SBEA
# W313RC1A027NBEA     Annual               A  W313RC1A027NBEA
# B050RC1A027NBEA     Annual               A  B050RC1A027NBEA
#
#                        last_updated  \
# series id
# A138RG3A086NBEA 2013-08-09 18:41:17
# A138RC1A027NBEA 2013-04-01 03:26:12
# B139RG3Q086SBEA 2018-04-27 12:54:42
# W313RC1A027NBEA 2017-10-27 14:05:00
# B050RC1A027NBEA 2018-03-28 12:54:34
#
#                                                              notes  \
# series id
# A138RG3A086NBEA  BEA Account Code: A138RG3  For more informatio...
# A138RC1A027NBEA  BEA Account Code: A138RC1  For more informatio...
# B139RG3Q086SBEA  BEA Account Code: B139RG  For more information...
# W313RC1A027NBEA  BEA Account Code: W313RC  For more information...
# B050RC1A027NBEA  BEA Account Code: B050RC  For more information...
#
#                 observation_end observation_start popularity realtime_end  \
# series id
# A138RG3A086NBEA      1966-01-01        1947-01-01          0   2018-05-24
# A138RC1A027NBEA      1966-01-01        1947-01-01          0   2018-05-24
# B139RG3Q086SBEA      2018-01-01        1947-01-01          0   2018-05-24
# W313RC1A027NBEA      2016-01-01        1946-01-01          0   2018-05-24
# B050RC1A027NBEA      2017-01-01        1929-01-01          0   2018-05-24
#
#                 realtime_start      seasonal_adjustment  \
# series id
# A138RG3A086NBEA     2018-05-24  Not Seasonally Adjusted
# A138RC1A027NBEA     2018-05-24  Not Seasonally Adjusted
# B139RG3Q086SBEA     2018-05-24      Seasonally Adjusted
# W313RC1A027NBEA     2018-05-24  Not Seasonally Adjusted
# B050RC1A027NBEA     2018-05-24  Not Seasonally Adjusted
#
#                 seasonal_adjustment_short  \
# series id
# A138RG3A086NBEA                       NSA
# A138RC1A027NBEA                       NSA
# B139RG3Q086SBEA                        SA
# W313RC1A027NBEA                       NSA
# B050RC1A027NBEA                       NSA
#
#                                                              title  \
# series id
# A138RG3A086NBEA  Automobile output: Private fixed investment (c...
# A138RC1A027NBEA  Automobile output: Private fixed investment (D...
# B139RG3Q086SBEA  Automobile output: Private fixed investment: N...
# W313RC1A027NBEA  Borrower services: Imputed interest paid: Rest...
# B050RC1A027NBEA  Capital consumption adjustment: Domestic nonco...
#
#                                units     units_short
# series id
# A138RG3A086NBEA       Index 2009=100  Index 2009=100
# A138RC1A027NBEA  Billions of Dollars       Bil. of $
# B139RG3Q086SBEA       Index 2009=100  Index 2009=100
# W313RC1A027NBEA  Billions of Dollars       Bil. of $
# B050RC1A027NBEA  Billions of Dollars       Bil. of $

# %%
data = fred.get_series('GDP')

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data.tail(20)
# Out:
# 2013-04-01    16541.390
# 2013-07-01    16749.349
# 2013-10-01    16999.888
# 2014-01-01    17031.324
# 2014-04-01    17320.921
# 2014-07-01    17622.257
# 2014-10-01    17735.933
# 2015-01-01    17874.715
# 2015-04-01    18093.224
# 2015-07-01    18227.689
# 2015-10-01    18287.226
# 2016-01-01    18325.187
# 2016-04-01    18538.039
# 2016-07-01    18729.130
# 2016-10-01    18905.545
# 2017-01-01    19057.705
# 2017-04-01    19250.009
# 2017-07-01    19500.602
# 2017-10-01    19754.102
# 2018-01-01    19965.326
# dtype: float64

# %%
import matplotlib

# %%
data.plot()
