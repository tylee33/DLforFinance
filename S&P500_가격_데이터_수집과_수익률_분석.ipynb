# %% [markdown]
# <a href="https://colab.research.google.com/github/tylee33/DLforFinance/blob/master/S%26P500_%EA%B0%80%EA%B2%A9_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%88%98%EC%A7%91%EA%B3%BC_%EC%88%98%EC%9D%B5%EB%A5%A0_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q finance-datareader

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (14,8)
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2
plt.rcParams["axes.grid"] = True
plt.rcParams['axes.axisbelow'] = True

# %% [markdown]
# # S&P500 종목 리스트

# %%
# S&P500 종목 리스트
import FinanceDataReader as fdr

sp500 = fdr.StockListing('S&P500')
sp500.head(10)
# Out:
#   Symbol                        Name                  Sector  \
# 0    MMM                  3M Company             Industrials
# 1    ABT         Abbott Laboratories             Health Care
# 2   ABBV                 AbbVie Inc.             Health Care
# 3   ABMD                 ABIOMED Inc             Health Care
# 4    ACN               Accenture plc  Information Technology
# 5   ATVI         Activision Blizzard  Communication Services
# 6   ADBE           Adobe Systems Inc  Information Technology
# 7    AMD  Advanced Micro Devices Inc  Information Technology
# 8    AAP          Advance Auto Parts  Consumer Discretionary
# 9    AES                    AES Corp               Utilities
#
#                                        Industry
# 0                      Industrial Conglomerates
# 1                         Health Care Equipment
# 2                               Pharmaceuticals
# 3                         Health Care Equipment
# 4                IT Consulting & Other Services
# 5                Interactive Home Entertainment
# 6                          Application Software
# 7                                Semiconductors
# 8                             Automotive Retail
# 9  Independent Power Producers & Energy Traders

# %%
# S&P500 종목은 실제 505개
len(sp500)
# Out:
# 505

# %% [markdown]
# # 데이터 수집과 저장

# %%
# 가격 데이터 가져오기 예시
import FinanceDataReader as fdr

aapl = fdr.DataReader('AAPL', '2010-01-01', '2018-12-31', country='US')
aapl.head(10)
# Out:
#             Close   Open   High    Low       Volume  Change
# Date
# 2010-01-04  30.57  30.49  30.64  30.34  123430000.0  0.0156
# 2010-01-05  30.63  30.66  30.80  30.46  150480000.0  0.0020
# 2010-01-06  30.14  30.63  30.75  30.11  138040000.0 -0.0160
# 2010-01-07  30.08  30.25  30.29  29.86  119280000.0 -0.0020
# 2010-01-08  30.28  30.04  30.29  29.87  111970000.0  0.0066
# 2010-01-11  30.02  30.40  30.43  29.78  115560000.0 -0.0086
# 2010-01-12  29.67  29.88  29.97  29.49  148610000.0 -0.0117
# 2010-01-13  30.09  29.70  30.13  29.16  151470000.0  0.0142
# 2010-01-14  29.92  30.02  30.07  29.86  108290000.0 -0.0056
# 2010-01-15  29.42  30.13  30.23  29.41  148580000.0 -0.0167

# %%
aapl.tail(10)
# Out:
#              Close    Open    High     Low      Volume  Change
# Date
# 2018-12-17  163.94  165.45  168.35  162.73  44290000.0 -0.0093
# 2018-12-18  166.07  165.38  167.53  164.39  33840000.0  0.0130
# 2018-12-19  160.89  166.00  167.45  159.09  49050000.0 -0.0312
# 2018-12-20  156.83  160.40  162.11  155.30  64770000.0 -0.0252
# 2018-12-21  150.73  156.86  158.16  149.63  95740000.0 -0.0389
# 2018-12-24  146.83  148.15  151.55  146.59  37170000.0 -0.0259
# 2018-12-26  157.17  148.30  157.23  146.72  58580000.0  0.0704
# 2018-12-27  156.15  155.84  156.77  150.07  53120000.0 -0.0065
# 2018-12-28  156.23  157.50  158.52  154.55  42290000.0  0.0005
# 2018-12-31  157.74  158.53  159.36  156.48  35000000.0  0.0097

# %% [markdown]
# # CSV 파일로 저장하기

# %%
# 디렉토리가 없으면 생성
import os
folder = "sp500_price/"
if not os.path.isdir(folder):
    os.mkdir(folder)

# %%
import csv
import pandas as pd

for ix, row in sp500.iterrows():
    sym, name = row['Symbol'], row['Name']
    csv_fn = folder + '%s.csv' % (sym)
    if os.path.exists(csv_fn):
        print('skip', csv_fn)
        continue

    df = fdr.DataReader(sym, '2010-01-01', '2018-12-31', country='US')
    df['Symbol'] = sym
    df.to_csv(csv_fn, quoting=csv.QUOTE_MINIMAL)
    print(csv_fn, len(df), 'rows')
# Out:
# skip sp500_price/MMM.csv
# skip sp500_price/ABT.csv
# skip sp500_price/ABBV.csv
# skip sp500_price/ABMD.csv
# skip sp500_price/ACN.csv
# skip sp500_price/ATVI.csv
# skip sp500_price/ADBE.csv
# skip sp500_price/AMD.csv
# skip sp500_price/AAP.csv
# skip sp500_price/AES.csv
# skip sp500_price/AMG.csv
# skip sp500_price/AFL.csv
# skip sp500_price/A.csv
# skip sp500_price/APD.csv
# skip sp500_price/AKAM.csv
# skip sp500_price/ALK.csv
# skip sp500_price/ALB.csv
# skip sp500_price/ARE.csv
# skip sp500_price/ALXN.csv
# skip sp500_price/ALGN.csv
# skip sp500_price/ALLE.csv
# skip sp500_price/AGN.csv
# skip sp500_price/ADS.csv
# skip sp500_price/LNT.csv
# skip sp500_price/ALL.csv
# skip sp500_price/GOOGL.csv
# skip sp500_price/GOOG.csv
# skip sp500_price/MO.csv
# skip sp500_price/AMZN.csv
# skip sp500_price/AEE.csv
# skip sp500_price/AAL.csv
# skip sp500_price/AEP.csv
# skip sp500_price/AXP.csv
# skip sp500_price/AIG.csv
# skip sp500_price/AMT.csv
# skip sp500_price/AWK.csv
# skip sp500_price/AMP.csv
# skip sp500_price/ABC.csv
# skip sp500_price/AME.csv
# skip sp500_price/AMGN.csv
# skip sp500_price/APH.csv
# skip sp500_price/APC.csv
# skip sp500_price/ADI.csv
# skip sp500_price/ANSS.csv
# skip sp500_price/ANTM.csv
# skip sp500_price/AON.csv
# skip sp500_price/AOS.csv
# skip sp500_price/APA.csv
# skip sp500_price/AIV.csv
# skip sp500_price/AAPL.csv
# skip sp500_price/AMAT.csv
# skip sp500_price/APTV.csv
# skip sp500_price/ADM.csv
# skip sp500_price/ARNC.csv
# skip sp500_price/ANET.csv
# skip sp500_price/AJG.csv
# skip sp500_price/AIZ.csv
# skip sp500_price/ATO.csv
# skip sp500_price/T.csv
# skip sp500_price/ADSK.csv
# skip sp500_price/ADP.csv
# skip sp500_price/AZO.csv
# skip sp500_price/AVB.csv
# skip sp500_price/AVY.csv
# skip sp500_price/BHGE.csv
# skip sp500_price/BLL.csv
# skip sp500_price/BAC.csv
# skip sp500_price/BK.csv
# skip sp500_price/BAX.csv
# skip sp500_price/BBT.csv
# skip sp500_price/BDX.csv
# skip sp500_price/BRKB.csv
# skip sp500_price/BBY.csv
# skip sp500_price/BIIB.csv
# skip sp500_price/BLK.csv
# skip sp500_price/HRB.csv
# skip sp500_price/BA.csv
# skip sp500_price/BKNG.csv
# skip sp500_price/BWA.csv
# skip sp500_price/BXP.csv
# skip sp500_price/BSX.csv
# skip sp500_price/BHF.csv
# skip sp500_price/BMY.csv
# skip sp500_price/AVGO.csv
# skip sp500_price/BR.csv
# skip sp500_price/BFB.csv
# skip sp500_price/CHRW.csv
# skip sp500_price/COG.csv
# skip sp500_price/CDNS.csv
# skip sp500_price/CPB.csv
# skip sp500_price/COF.csv
# skip sp500_price/CPRI.csv
# skip sp500_price/CAH.csv
# skip sp500_price/KMX.csv
# skip sp500_price/CCL.csv
# skip sp500_price/CAT.csv
# skip sp500_price/CBOE.csv
# skip sp500_price/CBRE.csv
# skip sp500_price/CBS.csv
# skip sp500_price/CE.csv
# skip sp500_price/CELG.csv
# skip sp500_price/CNC.csv
# skip sp500_price/CNP.csv
# skip sp500_price/CTL.csv
# skip sp500_price/CERN.csv
# skip sp500_price/CF.csv
# skip sp500_price/SCHW.csv
# skip sp500_price/CHTR.csv
# skip sp500_price/CVX.csv
# skip sp500_price/CMG.csv
# skip sp500_price/CB.csv
# skip sp500_price/CHD.csv
# skip sp500_price/CI.csv
# skip sp500_price/XEC.csv
# skip sp500_price/CINF.csv
# skip sp500_price/CTAS.csv
# skip sp500_price/CSCO.csv
# skip sp500_price/C.csv
# skip sp500_price/CFG.csv
# skip sp500_price/CTXS.csv
# skip sp500_price/CLX.csv
# skip sp500_price/CME.csv
# skip sp500_price/CMS.csv
# skip sp500_price/KO.csv
# skip sp500_price/CTSH.csv
# skip sp500_price/CL.csv
# skip sp500_price/CMCSA.csv
# skip sp500_price/CMA.csv
# skip sp500_price/CAG.csv
# skip sp500_price/CXO.csv
# skip sp500_price/COP.csv
# skip sp500_price/ED.csv
# skip sp500_price/STZ.csv
# skip sp500_price/COO.csv
# skip sp500_price/CPRT.csv
# skip sp500_price/GLW.csv
# skip sp500_price/COST.csv
# skip sp500_price/COTY.csv
# skip sp500_price/CCI.csv
# skip sp500_price/CSX.csv
# skip sp500_price/CMI.csv
# skip sp500_price/CVS.csv
# skip sp500_price/DHI.csv
# skip sp500_price/DHR.csv
# skip sp500_price/DRI.csv
# skip sp500_price/DVA.csv
# skip sp500_price/DE.csv
# skip sp500_price/DAL.csv
# skip sp500_price/XRAY.csv
# skip sp500_price/DVN.csv
# skip sp500_price/FANG.csv
# skip sp500_price/DLR.csv
# skip sp500_price/DFS.csv
# skip sp500_price/DISCA.csv
# skip sp500_price/DISCK.csv
# skip sp500_price/DISH.csv
# skip sp500_price/DG.csv
# skip sp500_price/DLTR.csv
# skip sp500_price/D.csv
# skip sp500_price/DOV.csv
# skip sp500_price/DWDP.csv
# skip sp500_price/DTE.csv
# skip sp500_price/DRE.csv
# skip sp500_price/DUK.csv
# skip sp500_price/DXC.csv
# skip sp500_price/ETFC.csv
# skip sp500_price/EMN.csv
# skip sp500_price/ETN.csv
# skip sp500_price/EBAY.csv
# skip sp500_price/ECL.csv
# skip sp500_price/EIX.csv
# skip sp500_price/EW.csv
# skip sp500_price/EA.csv
# skip sp500_price/EMR.csv
# skip sp500_price/ETR.csv
# skip sp500_price/EOG.csv
# skip sp500_price/EFX.csv
# skip sp500_price/EQIX.csv
# skip sp500_price/EQR.csv
# skip sp500_price/ESS.csv
# skip sp500_price/EL.csv
# skip sp500_price/EVRG.csv
# skip sp500_price/ES.csv
# skip sp500_price/RE.csv
# skip sp500_price/EXC.csv
# skip sp500_price/EXPE.csv
# skip sp500_price/EXPD.csv
# skip sp500_price/EXR.csv
# skip sp500_price/XOM.csv
# skip sp500_price/FFIV.csv
# skip sp500_price/FB.csv
# skip sp500_price/FAST.csv
# skip sp500_price/FRT.csv
# skip sp500_price/FDX.csv
# skip sp500_price/FIS.csv
# skip sp500_price/FITB.csv
# skip sp500_price/FE.csv
# skip sp500_price/FRC.csv
# skip sp500_price/FISV.csv
# skip sp500_price/FLT.csv
# skip sp500_price/FLIR.csv
# skip sp500_price/FLS.csv
# skip sp500_price/FLR.csv
# skip sp500_price/FMC.csv
# skip sp500_price/FL.csv
# skip sp500_price/F.csv
# skip sp500_price/FTNT.csv
# skip sp500_price/FTV.csv
# skip sp500_price/FBHS.csv
# skip sp500_price/BEN.csv
# skip sp500_price/FCX.csv
# skip sp500_price/GPS.csv
# skip sp500_price/GRMN.csv
# skip sp500_price/IT.csv
# skip sp500_price/GD.csv
# skip sp500_price/GE.csv
# skip sp500_price/GIS.csv
# skip sp500_price/GM.csv
# skip sp500_price/GPC.csv
# skip sp500_price/GILD.csv
# skip sp500_price/GPN.csv
# skip sp500_price/GS.csv
# skip sp500_price/GWW.csv
# skip sp500_price/HAL.csv
# skip sp500_price/HBI.csv
# skip sp500_price/HOG.csv
# skip sp500_price/HRS.csv
# skip sp500_price/HIG.csv
# skip sp500_price/HAS.csv
# skip sp500_price/HCA.csv
# skip sp500_price/HCP.csv
# skip sp500_price/HP.csv
# skip sp500_price/HSIC.csv
# skip sp500_price/HSY.csv
# skip sp500_price/HES.csv
# skip sp500_price/HPE.csv
# skip sp500_price/HLT.csv
# skip sp500_price/HFC.csv
# skip sp500_price/HOLX.csv
# skip sp500_price/HD.csv
# skip sp500_price/HON.csv
# skip sp500_price/HRL.csv
# skip sp500_price/HST.csv
# skip sp500_price/HPQ.csv
# skip sp500_price/HUM.csv
# skip sp500_price/HBAN.csv
# skip sp500_price/HII.csv
# skip sp500_price/IDXX.csv
# skip sp500_price/INFO.csv
# skip sp500_price/ITW.csv
# skip sp500_price/ILMN.csv
# skip sp500_price/IR.csv
# skip sp500_price/INTC.csv
# skip sp500_price/ICE.csv
# skip sp500_price/IBM.csv
# skip sp500_price/INCY.csv
# skip sp500_price/IP.csv
# skip sp500_price/IPG.csv
# skip sp500_price/IFF.csv
# skip sp500_price/INTU.csv
# skip sp500_price/ISRG.csv
# skip sp500_price/IVZ.csv
# skip sp500_price/IPGP.csv
# skip sp500_price/IQV.csv
# skip sp500_price/IRM.csv
# skip sp500_price/JKHY.csv
# skip sp500_price/JEC.csv
# skip sp500_price/JBHT.csv
# skip sp500_price/JEF.csv
# skip sp500_price/SJM.csv
# skip sp500_price/JNJ.csv
# skip sp500_price/JCI.csv
# skip sp500_price/JPM.csv
# skip sp500_price/JNPR.csv
# skip sp500_price/KSU.csv
# skip sp500_price/K.csv
# skip sp500_price/KEY.csv
# skip sp500_price/KEYS.csv
# skip sp500_price/KMB.csv
# skip sp500_price/KIM.csv
# skip sp500_price/KMI.csv
# skip sp500_price/KLAC.csv
# skip sp500_price/KSS.csv
# skip sp500_price/KHC.csv
# skip sp500_price/KR.csv
# skip sp500_price/LB.csv
# skip sp500_price/LLL.csv
# skip sp500_price/LH.csv
# skip sp500_price/LRCX.csv
# skip sp500_price/LW.csv
# skip sp500_price/LEG.csv
# skip sp500_price/LEN.csv
# skip sp500_price/LLY.csv
# skip sp500_price/LNC.csv
# skip sp500_price/LIN.csv
# skip sp500_price/LKQ.csv
# skip sp500_price/LMT.csv
# skip sp500_price/L.csv
# skip sp500_price/LOW.csv
# skip sp500_price/LYB.csv
# skip sp500_price/MTB.csv
# skip sp500_price/MAC.csv
# skip sp500_price/M.csv
# skip sp500_price/MRO.csv
# skip sp500_price/MPC.csv
# skip sp500_price/MAR.csv
# skip sp500_price/MMC.csv
# skip sp500_price/MLM.csv
# skip sp500_price/MAS.csv
# skip sp500_price/MA.csv
# skip sp500_price/MAT.csv
# skip sp500_price/MKC.csv
# skip sp500_price/MXIM.csv
# skip sp500_price/MCD.csv
# skip sp500_price/MCK.csv
# skip sp500_price/MDT.csv
# skip sp500_price/MRK.csv
# skip sp500_price/MET.csv
# skip sp500_price/MTD.csv
# skip sp500_price/MGM.csv
# skip sp500_price/MCHP.csv
# skip sp500_price/MU.csv
# skip sp500_price/MSFT.csv
# skip sp500_price/MAA.csv
# skip sp500_price/MHK.csv
# skip sp500_price/TAP.csv
# skip sp500_price/MDLZ.csv
# skip sp500_price/MNST.csv
# skip sp500_price/MCO.csv
# skip sp500_price/MS.csv
# skip sp500_price/MOS.csv
# skip sp500_price/MSI.csv
# skip sp500_price/MSCI.csv
# skip sp500_price/MYL.csv
# skip sp500_price/NDAQ.csv
# skip sp500_price/NOV.csv
# skip sp500_price/NKTR.csv
# skip sp500_price/NTAP.csv
# skip sp500_price/NFLX.csv
# skip sp500_price/NWL.csv
# skip sp500_price/NEM.csv
# skip sp500_price/NWSA.csv
# skip sp500_price/NWS.csv
# skip sp500_price/NEE.csv
# skip sp500_price/NLSN.csv
# skip sp500_price/NKE.csv
# skip sp500_price/NI.csv
# skip sp500_price/NBL.csv
# skip sp500_price/JWN.csv
# skip sp500_price/NSC.csv
# skip sp500_price/NTRS.csv
# skip sp500_price/NOC.csv
# skip sp500_price/NCLH.csv
# skip sp500_price/NRG.csv
# skip sp500_price/NUE.csv
# skip sp500_price/NVDA.csv
# skip sp500_price/ORLY.csv
# skip sp500_price/OXY.csv
# skip sp500_price/OMC.csv
# skip sp500_price/OKE.csv
# skip sp500_price/ORCL.csv
# skip sp500_price/PCAR.csv
# skip sp500_price/PKG.csv
# skip sp500_price/PH.csv
# skip sp500_price/PAYX.csv
# skip sp500_price/PYPL.csv
# skip sp500_price/PNR.csv
# skip sp500_price/PBCT.csv
# skip sp500_price/PEP.csv
# skip sp500_price/PKI.csv
# skip sp500_price/PRGO.csv
# skip sp500_price/PFE.csv
# skip sp500_price/PM.csv
# skip sp500_price/PSX.csv
# skip sp500_price/PNW.csv
# skip sp500_price/PXD.csv
# skip sp500_price/PNC.csv
# skip sp500_price/RL.csv
# skip sp500_price/PPG.csv
# skip sp500_price/PPL.csv
# skip sp500_price/PFG.csv
# skip sp500_price/PG.csv
# skip sp500_price/PGR.csv
# skip sp500_price/PLD.csv
# skip sp500_price/PRU.csv
# skip sp500_price/PEG.csv
# skip sp500_price/PSA.csv
# skip sp500_price/PHM.csv
# skip sp500_price/PVH.csv
# skip sp500_price/QRVO.csv
# skip sp500_price/PWR.csv
# skip sp500_price/QCOM.csv
# skip sp500_price/DGX.csv
# skip sp500_price/RJF.csv
# skip sp500_price/RTN.csv
# skip sp500_price/O.csv
# skip sp500_price/RHT.csv
# skip sp500_price/REG.csv
# skip sp500_price/REGN.csv
# skip sp500_price/RF.csv
# skip sp500_price/RSG.csv
# skip sp500_price/RMD.csv
# skip sp500_price/RHI.csv
# skip sp500_price/ROK.csv
# skip sp500_price/ROL.csv
# skip sp500_price/ROP.csv
# skip sp500_price/ROST.csv
# skip sp500_price/RCL.csv
# skip sp500_price/CRM.csv
# skip sp500_price/SBAC.csv
# skip sp500_price/SLB.csv
# skip sp500_price/STX.csv
# skip sp500_price/SEE.csv
# skip sp500_price/SRE.csv
# skip sp500_price/SHW.csv
# skip sp500_price/SPG.csv
# skip sp500_price/SWKS.csv
# skip sp500_price/SLG.csv
# skip sp500_price/SNA.csv
# skip sp500_price/SO.csv
# skip sp500_price/LUV.csv
# skip sp500_price/SPGI.csv
# skip sp500_price/SWK.csv
# skip sp500_price/SBUX.csv
# skip sp500_price/STT.csv
# skip sp500_price/SYK.csv
# skip sp500_price/STI.csv
# skip sp500_price/SIVB.csv
# skip sp500_price/SYMC.csv
# skip sp500_price/SYF.csv
# skip sp500_price/SNPS.csv
# skip sp500_price/SYY.csv
# skip sp500_price/TROW.csv
# skip sp500_price/TTWO.csv
# skip sp500_price/TPR.csv
# skip sp500_price/TGT.csv
# skip sp500_price/TEL.csv
# skip sp500_price/FTI.csv
# skip sp500_price/TFX.csv
# skip sp500_price/TXN.csv
# skip sp500_price/TXT.csv
# skip sp500_price/TMO.csv
# skip sp500_price/TIF.csv
# skip sp500_price/TWTR.csv
# skip sp500_price/TJX.csv
# skip sp500_price/TMK.csv
# skip sp500_price/TSS.csv
# skip sp500_price/TSCO.csv
# skip sp500_price/TDG.csv
# skip sp500_price/TRV.csv
# skip sp500_price/TRIP.csv
# skip sp500_price/FOXA.csv
# skip sp500_price/FOX.csv
# skip sp500_price/TSN.csv
# skip sp500_price/UDR.csv
# skip sp500_price/ULTA.csv
# skip sp500_price/USB.csv
# skip sp500_price/UAA.csv
# skip sp500_price/UA.csv
# skip sp500_price/UNP.csv
# skip sp500_price/UAL.csv
# skip sp500_price/UNH.csv
# skip sp500_price/UPS.csv
# skip sp500_price/URI.csv
# skip sp500_price/UTX.csv
# skip sp500_price/UHS.csv
# skip sp500_price/UNM.csv
# skip sp500_price/VFC.csv
# skip sp500_price/VLO.csv
# skip sp500_price/VAR.csv
# skip sp500_price/VTR.csv
# skip sp500_price/VRSN.csv
# skip sp500_price/VRSK.csv
# skip sp500_price/VZ.csv
# skip sp500_price/VRTX.csv
# skip sp500_price/VIAB.csv
# skip sp500_price/V.csv
# skip sp500_price/VNO.csv
# skip sp500_price/VMC.csv
# skip sp500_price/WAB.csv
# skip sp500_price/WMT.csv
# skip sp500_price/WBA.csv
# skip sp500_price/DIS.csv
# skip sp500_price/WM.csv
# skip sp500_price/WAT.csv
# skip sp500_price/WEC.csv
# skip sp500_price/WCG.csv
# skip sp500_price/WFC.csv
# skip sp500_price/WELL.csv
# skip sp500_price/WDC.csv
# skip sp500_price/WU.csv
# skip sp500_price/WRK.csv
# skip sp500_price/WY.csv
# skip sp500_price/WHR.csv
# skip sp500_price/WMB.csv
# skip sp500_price/WLTW.csv
# skip sp500_price/WYNN.csv
# skip sp500_price/XEL.csv
# skip sp500_price/XRX.csv
# skip sp500_price/XLNX.csv
# skip sp500_price/XYL.csv
# skip sp500_price/YUM.csv
# skip sp500_price/ZBH.csv
# skip sp500_price/ZION.csv
# skip sp500_price/ZTS.csv

# %%
# 읽어서 확인
sym = 'AAPL'
csv_fn = folder + '%s.csv' % (sym)
aapl = pd.read_csv(csv_fn, parse_dates=True, index_col='Date')
aapl.head()
# Out:
#             Close   Open   High    Low       Volume  Change Symbol
# Date
# 2010-01-04  30.57  30.49  30.64  30.34  123430000.0  0.0156   AAPL
# 2010-01-05  30.63  30.66  30.80  30.46  150480000.0  0.0020   AAPL
# 2010-01-06  30.14  30.63  30.75  30.11  138040000.0 -0.0160   AAPL
# 2010-01-07  30.08  30.25  30.29  29.86  119280000.0 -0.0020   AAPL
# 2010-01-08  30.28  30.04  30.29  29.87  111970000.0  0.0066   AAPL

# %%
aapl.tail()
# Out:
#              Close    Open    High     Low      Volume  Change Symbol
# Date
# 2018-12-24  146.83  148.15  151.55  146.59  37170000.0 -0.0259   AAPL
# 2018-12-26  157.17  148.30  157.23  146.72  58580000.0  0.0704   AAPL
# 2018-12-27  156.15  155.84  156.77  150.07  53120000.0 -0.0065   AAPL
# 2018-12-28  156.23  157.50  158.52  154.55  42290000.0  0.0005   AAPL
# 2018-12-31  157.74  158.53  159.36  156.48  35000000.0  0.0097   AAPL

# %% [markdown]
# # S&P500 지수

# %%
us500 = fdr.DataReader('US500', '2010-01-01', '2018-12-31')
us500.head()
# Out:
#               Close     Open     High      Low  Volume  Change
# Date
# 2010-01-04  1132.99  1116.56  1133.87  1116.56     0.0  0.0160
# 2010-01-05  1136.52  1132.66  1136.63  1129.66     0.0  0.0031
# 2010-01-06  1137.14  1135.71  1139.19  1133.95     0.0  0.0005
# 2010-01-07  1141.69  1136.27  1142.46  1131.32     0.0  0.0040
# 2010-01-08  1144.98  1140.52  1145.39  1136.22     0.0  0.0029

# %%
df_plot = pd.DataFrame()

df_plot['S&P500'] = us500['Close']
df_plot['AAPL'] = aapl['Close']

df_plot = df_plot / df_plot.iloc[0] - 1.0
df_plot.plot()

# %%
changes = us500['Close'].pct_change()

(changes + 1).product() - 1
# Out:
# 1.2125967572529373

# %%
changes = aapl['Close'].pct_change()

(changes + 1).product() - 1
# Out:
# 4.1599607458292525

# %% [markdown]
# # S&P500 전체 종목의 가격

# %%
df_price = pd.DataFrame() 

for ix, row in sp500.iterrows():
  sym = row['Symbol']
  csv_fn = folder + '%s.csv' % (sym)
  try:
    df = pd.read_csv(csv_fn,parse_dates={'date':[0]},index_col='date')
    df.dropna()
  except TypeError:
    pass
  df_price[sym] = df['Close']

# %%
df_price.tail(10)
# Out:
#                MMM    ABT   ABBV    ABMD     ACN   ATVI    ADBE    AMD  \
# date
# 2018-12-17  192.82  69.75  84.93  298.77  151.67  47.08  221.38  18.83
# 2018-12-18  194.56  70.08  83.58  304.80  152.14  47.32  226.18  19.50
# 2018-12-19  189.96  69.00  83.52  296.14  150.96  46.33  224.65  18.16
# 2018-12-20  187.38  68.38  85.37  284.28  143.50  47.05  218.65  17.94
# 2018-12-21  183.75  67.27  84.92  290.29  137.20  45.85  208.80  16.93
# 2018-12-24  178.62  65.56  84.16  281.08  133.67  43.99  205.16  16.65
# 2018-12-26  186.26  69.62  89.04  307.44  139.01  46.42  222.95  17.90
# 2018-12-27  190.70  70.63  89.91  315.67  140.41  47.04  225.14  17.49
# 2018-12-28  189.37  71.09  91.12  318.17  139.82  46.80  223.13  17.82
# 2018-12-31  190.54  72.33  92.19  325.04  141.01  46.57  226.24  18.46
#
#                AAP    AES  ...      WLTW    WYNN    XEL    XRX   XLNX    XYL  \
# date                       ...
# 2018-12-17  158.84  14.88  ...    151.28  104.48  51.73  21.29  87.18  64.30
# 2018-12-18  158.24  14.98  ...    151.93  103.09  51.49  21.07  89.23  64.39
# 2018-12-19  156.12  14.74  ...    151.33   98.39  50.92  20.67  85.22  65.13
# 2018-12-20  152.50  14.69  ...    149.34   97.80  51.37  19.56  83.48  63.86
# 2018-12-21  151.41  14.45  ...    147.07   93.41  50.90  19.33  81.51  63.44
# 2018-12-24  148.92  13.82  ...    146.61   92.01  48.60  18.92  79.27  61.38
# 2018-12-26  155.03  14.28  ...    148.86   99.23  49.56  19.70  85.22  64.27
# 2018-12-27  154.69  14.29  ...    150.85   98.12  49.60  19.68  84.30  65.35
# 2018-12-28  155.46  14.27  ...    150.93   97.24  49.25  19.65  84.34  65.30
# 2018-12-31  157.46  14.46  ...    151.86   98.91  49.27  19.76  85.17  66.72
#
#               YUM     ZBH   ZION    ZTS
# date
# 2018-12-17  89.71  107.25  41.19  84.94
# 2018-12-18  90.10  105.78  40.76  84.99
# 2018-12-19  90.12  104.56  40.13  83.44
# 2018-12-20  87.12  101.77  39.74  82.42
# 2018-12-21  88.14   99.38  39.06  81.68
# 2018-12-24  87.02   97.23  38.51  79.28
# 2018-12-26  89.99  102.02  40.51  82.92
# 2018-12-27  90.96  101.71  40.46  84.33
# 2018-12-28  91.61  102.65  40.43  84.49
# 2018-12-31  91.92  103.72  40.74  85.54
#
# [10 rows x 505 columns]

# %%
df_price.columns
# Out:
# Index(['MMM', 'ABT', 'ABBV', 'ABMD', 'ACN', 'ATVI', 'ADBE', 'AMD', 'AAP',
#        'AES',
#        ...
#        'WLTW', 'WYNN', 'XEL', 'XRX', 'XLNX', 'XYL', 'YUM', 'ZBH', 'ZION',
#        'ZTS'],
#       dtype='object', length=505)

# %%
len(df_price.columns)
# Out:
# 505

# %% [markdown]
# # 2018 수익률 Best, Worst 20
#
# *   df.pct_change()
# *   (df_price['2018'].pct_change()+1).product()-1

# %%
returns = (df_price['2018'].pct_change() + 1).product() - 1
returns = returns.sort_values(ascending=False)

# Best 20
best20 = returns.head(20)
best20
# Out:
# ABMD    0.688607
# AMD     0.681239
# FTNT    0.588050
# TRIP    0.551337
# FOXA    0.551337
# FOX     0.551337
# AAP     0.484212
# CMG     0.473938
# KEYS    0.472835
# RHT     0.451091
# BSX     0.397943
# HCA     0.390347
# ORLY    0.381409
# MKC     0.375482
# EW      0.372737
# NRG     0.370242
# LLY     0.366556
# MRK     0.359125
# VRSN    0.354618
# ILMN    0.338794
# dtype: float64

# %%
# Worst 20

worst20 = returns.tail(20)[::-1]
worst20
# Out:
# COTY   -0.670020
# GE     -0.578977
# MHK    -0.576232
# LB     -0.571381
# PRGO   -0.567956
# WDC    -0.545711
# IVZ    -0.539477
# AMG    -0.520095
# XEC    -0.508804
# DISH   -0.502590
# IPGP   -0.490465
# SLB    -0.481013
# FCX    -0.478503
# BHF    -0.471476
# DVN    -0.466256
# UNM    -0.464455
# HAL    -0.464221
# PNR    -0.462053
# FBHS   -0.447338
# XRAY   -0.445785
# dtype: float64

# %% [markdown]
# # 2018 수익률 상위 10
#
#
# 1.   ABMD (아비오메드) - 심장 보조장치 기술 개발 기업
# 2.   AMD (에이엠디) - 그래픽카드, 집적회로 제조사
# 3.   FTNT (포티넷) - 네트워크 보안 장비
# 4.   TRIP (트립어드바이저) - 호텔 등 여행에 관한 가격 비교
# 5.   AAP (어드밴스 오토 파치) - 자동차 부품, 자동차 에프터 마켓
# 6.   RHT (레드헷) - 리눅스 배포판 제작회사
# 7.   BHT (보스턴 사이언티픽) - 의료장비
# 8.   HCA (HCA 홀딩스) - 헬스케어
# 9.   ORLY (오릴리 오토모티브) - 자동차 전장 부품 애프터 마켓
# 10. MKC (멕코믹 앤 컴퍼니) - 향신료, 조미료 믹스

# %%
# Best 10
best10 = returns.head(10)
best10
# Out:
# ABMD    0.688607
# AMD     0.681239
# FTNT    0.588050
# TRIP    0.551337
# FOXA    0.551337
# FOX     0.551337
# AAP     0.484212
# CMG     0.473938
# KEYS    0.472835
# RHT     0.451091
# dtype: float64

# %%
df_price.loc['2018', best10.keys()].head(20)
# Out:
#               ABMD    AMD   FTNT   TRIP   FOXA    FOX     AAP     CMG   KEYS  \
# date
# 2018-01-02  192.49  10.98  44.35  34.77  34.77  34.77  106.09  292.95  42.15
# 2018-01-03  195.82  11.55  45.03  34.97  34.97  34.97  107.05  309.00  42.75
# 2018-01-04  199.25  12.12  44.00  34.92  34.92  34.92  111.00  307.11  42.96
# 2018-01-05  202.32  11.88  44.10  34.73  34.73  34.73  112.18  313.79  43.92
# 2018-01-08  207.80  12.28  45.00  34.67  34.67  34.67  111.39  318.47  44.57
# 2018-01-09  209.76  11.82  44.32  34.59  34.59  34.59  110.49  319.37  45.15
# 2018-01-10  208.14  11.96  44.10  34.49  34.49  34.49  110.59  321.80  44.34
# 2018-01-11  210.15  12.14  44.26  35.28  35.28  35.28  112.95  325.50  44.92
# 2018-01-12  215.11  12.02  44.94  36.54  36.54  36.54  115.94  327.34  44.82
# 2018-01-16  218.09  11.91  44.34  35.89  35.89  35.89  113.90  327.37  44.75
# 2018-01-17  224.13  12.18  45.09  35.90  35.90  35.90  115.35  334.63  46.01
# 2018-01-18  225.89  12.47  45.71  35.62  35.62  35.62  115.53  337.53  45.77
# 2018-01-19  228.29  12.59  46.01  35.45  35.45  35.45  117.02  343.87  46.33
# 2018-01-22  228.18  12.65  45.85  37.20  37.20  37.20  118.03  330.00  46.48
# 2018-01-23  230.27  12.94  45.75  36.30  36.30  36.30  119.10  328.71  46.55
# 2018-01-24  232.95  12.71  45.25  36.31  36.31  36.31  120.99  329.53  46.03
# 2018-01-25  236.32  12.41  45.41  36.49  36.49  36.49  120.92  333.97  45.74
# 2018-01-26  238.89  12.95  45.86  36.78  36.78  36.78  123.64  330.23  46.58
# 2018-01-29  236.65  13.32  45.96  36.33  36.33  36.33  122.89  332.33  47.65
# 2018-01-30  235.06  12.87  45.74  34.90  34.90  34.90  119.27  322.08  47.20
#
#                RHT
# date
# 2018-01-02  121.04
# 2018-01-03  123.06
# 2018-01-04  123.98
# 2018-01-05  124.14
# 2018-01-08  125.21
# 2018-01-09  124.15
# 2018-01-10  124.51
# 2018-01-11  126.16
# 2018-01-12  125.95
# 2018-01-16  124.59
# 2018-01-17  126.60
# 2018-01-18  125.47
# 2018-01-19  125.94
# 2018-01-22  128.01
# 2018-01-23  128.15
# 2018-01-24  128.89
# 2018-01-25  130.90
# 2018-01-26  135.22
# 2018-01-29  132.95
# 2018-01-30  131.46

# %%
import matplotlib as mpl
import numpy as np

def make_colors(n, colormap=plt.cm.Spectral):
    return colormap(np.linspace(0.1, 1.0, n))

# %%
df_plot = pd.DataFrame()

df_plot['S&P500'] = us500.loc['2018', 'Close'] # S&P500 지수
df_plot[best10.keys()] = df_price.loc['2018', best10.keys()] # 10개 종목

df_plot = df_plot / df_plot.iloc[0] - 1
df_plot.plot(color=make_colors(11))

# %%
worst10 = returns.tail(10)[::-1]

# %%
df_plot = pd.DataFrame()

df_plot['S&P500'] = us500.loc['2018', 'Close'] # S&P500 지수
df_plot[worst10.keys()] = df_price.loc['2018', worst10.keys()] # 10개 종목

df_plot = df_plot / df_plot.iloc[0] - 1
df_plot.plot(color=make_colors(11))

# %% [markdown]
# # 수익률

# %%
df = pd.DataFrame()

df['S&P500'] = us500.loc['2018', 'Close'] # S&P500 지수
df[best20.keys()] = df_price.loc['2018', best20.keys()]

# %%
df.head(20)
# Out:
#              S&P500    ABMD    AMD   FTNT   TRIP   FOXA    FOX     AAP  \
# Date
# 2018-01-02  2695.81  192.49  10.98  44.35  34.77  34.77  34.77  106.09
# 2018-01-03  2713.06  195.82  11.55  45.03  34.97  34.97  34.97  107.05
# 2018-01-04  2723.99  199.25  12.12  44.00  34.92  34.92  34.92  111.00
# 2018-01-05  2743.15  202.32  11.88  44.10  34.73  34.73  34.73  112.18
# 2018-01-08  2747.71  207.80  12.28  45.00  34.67  34.67  34.67  111.39
# 2018-01-09  2751.29  209.76  11.82  44.32  34.59  34.59  34.59  110.49
# 2018-01-10  2748.23  208.14  11.96  44.10  34.49  34.49  34.49  110.59
# 2018-01-11  2767.56  210.15  12.14  44.26  35.28  35.28  35.28  112.95
# 2018-01-12  2786.24  215.11  12.02  44.94  36.54  36.54  36.54  115.94
# 2018-01-16  2776.42  218.09  11.91  44.34  35.89  35.89  35.89  113.90
# 2018-01-17  2802.56  224.13  12.18  45.09  35.90  35.90  35.90  115.35
# 2018-01-18  2798.03  225.89  12.47  45.71  35.62  35.62  35.62  115.53
# 2018-01-19  2810.30  228.29  12.59  46.01  35.45  35.45  35.45  117.02
# 2018-01-22  2832.97  228.18  12.65  45.85  37.20  37.20  37.20  118.03
# 2018-01-23  2839.13  230.27  12.94  45.75  36.30  36.30  36.30  119.10
# 2018-01-24  2837.54  232.95  12.71  45.25  36.31  36.31  36.31  120.99
# 2018-01-25  2839.25  236.32  12.41  45.41  36.49  36.49  36.49  120.92
# 2018-01-26  2872.87  238.89  12.95  45.86  36.78  36.78  36.78  123.64
# 2018-01-29  2853.53  236.65  13.32  45.96  36.33  36.33  36.33  122.89
# 2018-01-30  2822.43  235.06  12.87  45.74  34.90  34.90  34.90  119.27
#
#                CMG   KEYS   ...      BSX     HCA    ORLY     MKC      EW  \
# Date                        ...
# 2018-01-02  292.95  42.15   ...    25.28   89.51  249.26  101.23  111.58
# 2018-01-03  309.00  42.75   ...    25.56   87.04  253.84  101.47  114.59
# 2018-01-04  307.11  42.96   ...    25.32   85.96  257.68  102.11  115.41
# 2018-01-05  313.79  43.92   ...    25.97   86.93  260.28  103.11  115.86
# 2018-01-08  318.47  44.57   ...    25.81   86.75  260.00  103.22  118.14
# 2018-01-09  319.37  45.15   ...    27.96   86.00  261.26  103.12  119.51
# 2018-01-10  321.80  44.34   ...    27.52   84.96  258.45  101.58  118.50
# 2018-01-11  325.50  44.92   ...    27.43   86.97  259.75  101.00  119.99
# 2018-01-12  327.34  44.82   ...    27.46   88.80  258.60  101.01  120.83
# 2018-01-16  327.37  44.75   ...    26.98   88.79  257.89  101.29  120.07
# 2018-01-17  334.63  46.01   ...    27.25   89.40  265.04  102.65  120.49
# 2018-01-18  337.53  45.77   ...    27.40   90.11  266.33  102.91  121.72
# 2018-01-19  343.87  46.33   ...    27.65   93.01  273.02   99.19  123.91
# 2018-01-22  330.00  46.48   ...    27.71   92.86  272.30   99.13  124.51
# 2018-01-23  328.71  46.55   ...    27.82   91.73  271.21   98.89  124.40
# 2018-01-24  329.53  46.03   ...    27.91   91.49  275.93  100.09  124.79
# 2018-01-25  333.97  45.74   ...    28.26   92.83  272.88  105.09  126.24
# 2018-01-26  330.23  46.58   ...    28.42   97.07  275.47  107.45  128.16
# 2018-01-29  332.33  47.65   ...    28.33   97.62  273.94  107.78  126.90
# 2018-01-30  322.08  47.20   ...    28.03  101.45  268.27  107.97  126.74
#
#               NRG    LLY    MRK    VRSN    ILMN
# Date
# 2018-01-02  28.90  84.68  56.22  109.47  224.03
# 2018-01-03  28.88  85.14  56.14  110.90  230.32
# 2018-01-04  28.55  85.52  57.05  111.47  232.99
# 2018-01-05  28.73  86.57  56.99  113.00  228.17
# 2018-01-08  29.17  86.13  56.66  114.31  227.06
# 2018-01-09  28.72  86.06  56.80  112.97  242.80
# 2018-01-10  28.24  86.10  57.30  111.96  242.59
# 2018-01-11  28.61  86.39  57.60  112.23  240.04
# 2018-01-12  28.70  86.98  58.66  113.61  244.72
# 2018-01-16  27.90  85.29  62.07  112.65  241.42
# 2018-01-17  27.43  86.21  62.03  114.00  242.05
# 2018-01-18  26.81  85.82  61.13  114.54  241.31
# 2018-01-19  26.90  85.49  61.28  114.48  243.55
# 2018-01-22  26.92  85.44  61.25  114.46  245.19
# 2018-01-23  27.14  84.42  61.70  115.77  242.94
# 2018-01-24  27.25  84.30  61.18  115.77  242.49
# 2018-01-25  27.65  85.01  61.30  115.99  243.39
# 2018-01-26  27.40  87.08  62.04  115.31  244.83
# 2018-01-29  26.86  87.60  61.63  112.41  241.78
# 2018-01-30  26.09  86.09  60.65  112.15  241.18
#
# [20 rows x 21 columns]

# %%
# 종목간 상관관계
changes = df.pct_change()
corr = changes.corr()
corr.head(10)
# Out:
#           S&P500      ABMD       AMD      FTNT      TRIP      FOXA       FOX  \
# S&P500  1.000000  0.569708  0.477572  0.571172  0.430621  0.430621  0.430621
# ABMD    0.569708  1.000000  0.428237  0.429916  0.281890  0.281890  0.281890
# AMD     0.477572  0.428237  1.000000  0.383637  0.187769  0.187769  0.187769
# FTNT    0.571172  0.429916  0.383637  1.000000  0.301569  0.301569  0.301569
# TRIP    0.430621  0.281890  0.187769  0.301569  1.000000  1.000000  1.000000
# FOXA    0.430621  0.281890  0.187769  0.301569  1.000000  1.000000  1.000000
# FOX     0.430621  0.281890  0.187769  0.301569  1.000000  1.000000  1.000000
# AAP     0.450201  0.259196  0.263973  0.262070  0.251901  0.251901  0.251901
# CMG     0.321624  0.273492  0.323716  0.209000  0.069957  0.069957  0.069957
# KEYS    0.645429  0.484956  0.383873  0.508740  0.326940  0.326940  0.326940
#
#              AAP       CMG      KEYS    ...          BSX       HCA      ORLY  \
# S&P500  0.450201  0.321624  0.645429    ...     0.699311  0.564631  0.500503
# ABMD    0.259196  0.273492  0.484956    ...     0.493292  0.314510  0.259567
# AMD     0.263973  0.323716  0.383873    ...     0.322902  0.286902  0.325657
# FTNT    0.262070  0.209000  0.508740    ...     0.436283  0.375518  0.284094
# TRIP    0.251901  0.069957  0.326940    ...     0.297751  0.268466  0.244817
# FOXA    0.251901  0.069957  0.326940    ...     0.297751  0.268466  0.244817
# FOX     0.251901  0.069957  0.326940    ...     0.297751  0.268466  0.244817
# AAP     1.000000  0.321631  0.293006    ...     0.331574  0.245492  0.668117
# CMG     0.321631  1.000000  0.208942    ...     0.300140  0.166016  0.472314
# KEYS    0.293006  0.208942  1.000000    ...     0.496903  0.334677  0.334095
#
#              MKC        EW       NRG       LLY       MRK      VRSN      ILMN
# S&P500  0.471124  0.661642  0.490372  0.574360  0.584788  0.576832  0.734444
# ABMD    0.239491  0.632496  0.329429  0.229735  0.289235  0.504020  0.546543
# AMD     0.232912  0.435703  0.215920  0.099704  0.178059  0.362935  0.392523
# FTNT    0.298439  0.521784  0.277399  0.248450  0.228850  0.259941  0.501135
# TRIP    0.184022  0.378045  0.173888  0.130287  0.234424  0.266324  0.380754
# FOXA    0.184022  0.378045  0.173888  0.130287  0.234424  0.266324  0.380754
# FOX     0.184022  0.378045  0.173888  0.130287  0.234424  0.266324  0.380754
# AAP     0.272004  0.283381  0.192488  0.257228  0.248829  0.254443  0.354309
# CMG     0.166115  0.175030  0.132275  0.214011  0.089821  0.277856  0.236383
# KEYS    0.202441  0.504865  0.348530  0.339814  0.355343  0.431178  0.570415
#
# [10 rows x 21 columns]

# %%
# 상관관계 히트맵

plt.figure(figsize=(16,8))
plt.grid(False)
plt.imshow(corr, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation=90)
plt.yticks(range(len(corr)), corr.columns)
plt.show()

# %%
# 상관계수 순위 만들기 (수익률 상위 20종목)
import pandas as pd

idx, vals = [], []
for ix, i in enumerate(corr.columns.values):
    for j in corr.columns.values[ix + 1:]:
        idx.append((i, j))
        vals.append(corr[i][j])

ser = pd.Series(data=vals, index=idx)
ser_ord = ser.sort_values(ascending=False)
ser_ord[:20]
# Out:
# (TRIP, FOXA)      1.000000
# (FOXA, FOX)       1.000000
# (TRIP, FOX)       1.000000
# (S&P500, ILMN)    0.734444
# (S&P500, BSX)     0.699311
# (AAP, ORLY)       0.668117
# (S&P500, EW)      0.661642
# (S&P500, KEYS)    0.645429
# (BSX, ILMN)       0.641143
# (ABMD, EW)        0.632496
# (EW, ILMN)        0.631954
# (VRSN, ILMN)      0.609666
# (S&P500, MRK)     0.584788
# (S&P500, VRSN)    0.576832
# (S&P500, LLY)     0.574360
# (LLY, MRK)        0.573635
# (S&P500, FTNT)    0.571172
# (KEYS, ILMN)      0.570415
# (S&P500, ABMD)    0.569708
# (S&P500, HCA)     0.564631
# dtype: float64

# %%
# 지수와 상관관계
changes = df.pct_change()
corr = changes.corr()
corr['S&P500'].sort_values(ascending=False)[1:]
# Out:
# ILMN    0.734444
# BSX     0.699311
# EW      0.661642
# KEYS    0.645429
# MRK     0.584788
# VRSN    0.576832
# LLY     0.574360
# FTNT    0.571172
# ABMD    0.569708
# HCA     0.564631
# ORLY    0.500503
# NRG     0.490372
# AMD     0.477572
# MKC     0.471124
# AAP     0.450201
# FOX     0.430621
# FOXA    0.430621
# TRIP    0.430621
# CMG     0.321624
# RHT     0.202931
# Name: S&P500, dtype: float64

# %% [markdown]
# # 스캐터 차트, 수익과 위험 분석
#
#
# *   수익(returns) : 수익률 평균 (mean)
# *   위험(risk) : 표준편차 (std)

# %%
plt.figure(figsize=(16,8))
plt.scatter(changes.mean(), changes.std())
plt.xlabel('returns')
plt.ylabel('risk')
plt.xlim(-0.001, 0.003)
for label, x, y in zip(changes.columns, changes.mean(), changes.std()):
    plt.annotate( label, xy=(x, y), xytext=(30, -30),
    textcoords = 'offset points',
    ha = 'right', va = 'bottom',
    bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
    arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

# %% [markdown]
# # 전체 종목에서 2018년 수익률 상관관계 상위 종목

# %%
df = pd.DataFrame()

df['S&P500'] = us500.loc['2018', 'Close'] # S&P500 지수
df[df_price.columns] = df_price.loc['2018', df_price.columns]

# 종목간 상관관계
changes = df.pct_change()
corr = changes.corr()

idx, vals = [], []
for ix, i in enumerate(corr.columns.values):
    for j in corr.columns.values[ix + 1:]:
        idx.append((i, j))
        vals.append(corr[i][j])

ser = pd.Series(data=vals, index=idx)
ser_ord = ser.sort_values(ascending=False)
ser_ord[:40]
# Out:
# (FOXA, FOX)       1.000000
# (TRIP, FOX)       1.000000
# (TRIP, FOXA)      1.000000
# (GOOGL, GOOG)     0.993665
# (DISCA, DISCK)    0.985300
# (UAA, UA)         0.975314
# (NWSA, NWS)       0.972784
# (BAC, JPM)        0.930777
# (AVB, UDR)        0.928910
# (CMS, WEC)        0.927522
# (WEC, XEL)        0.921569
# (MAA, UDR)        0.919998
# (CMS, XEL)        0.919797
# (AEP, XEL)        0.917240
# (EQR, UDR)        0.914252
# (MA, V)           0.913769
# (LNT, XEL)        0.912091
# (AIV, UDR)        0.912072
# (LNT, WEC)        0.911992
# (AVB, MAA)        0.910552
# (AVB, EQR)        0.910551
# (CMS, DTE)        0.904068
# (LNT, AEP)        0.904028
# (LNT, CMS)        0.901618
# (AEE, CMS)        0.901259
# (LNC, PRU)        0.899293
# (AEP, CMS)        0.897136
# (LNT, AEE)        0.896079
# (AEE, WEC)        0.895750
# (ED, WEC)         0.894669
# (AIV, MAA)        0.893404
# (HBAN, KEY)       0.891844
# (AIV, AVB)        0.891155
# (CMA, KEY)        0.889040
# (CMS, ED)         0.887810
# (HBAN, RF)        0.887089
# (AEE, XEL)        0.886097
# (DTE, XEL)        0.886022
# (AEP, WEC)        0.885764
# (DUK, WEC)        0.885178
# dtype: float64

# %% [markdown]
# # 상관계수가 높은 페어 종목

# %%
df_price[['BAC', 'JPM']].plot()

# %%
df_plot = df_price[['BAC', 'JPM']]
df_plot = df_plot / (df_plot.max() - df_plot.min())
df_plot.plot()

# %%
df_price[['MAA', 'UDR']].plot()

# %%
df_plot = df_price[['MAA', 'UDR']]
df_plot = df_plot / (df_plot.max() - df_plot.min())
df_plot.plot()
