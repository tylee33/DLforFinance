# %%
from pandas_datareader import data
import fix_yahoo_finance as yf

# %%
yf.pdr_override()

start_date = '1996-05-06' #startdate를 1996년으로 설정해두면 가장 오래된 데이터부터 전부 가져올 수 있다.
tickers = ['067160.KQ', '035420.KS'] #1 아프리카tv와 네이버의 ticker(종목코드)
afreeca = data.get_data_yahoo(tickers[0], start_date)
naver = data.get_data_yahoo(tickers[1], start_date)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded

# %% [markdown]
# #1
# 주목해야 할 점은 아프리카tv는 코스닥 종목이고, 네이버는 코스피 종목이라는 것.
# 코스닥은 ticker에 `.KQ`, 코스피는 `.KS`가 붙는다.
# #2
# data객체의 get_data_yahoo 를 이용해서 얻은 데이터들(아프리카, 네이버)은 DataFrame형의 객체이다.
# (정확히는 pandas.core.frame.DataFrame)
# data객체가 pandas-datareader에서 가져온 것임을 잊지말자

# %%
afreeca.head()
# Out:
#               Open    High     Low   Close    Adj Close   Volume
# Date
# 2003-12-22  3485.0  3485.0  3485.0  3485.0  2924.239502    18600
# 2003-12-23  3070.0  3290.0  3070.0  3070.0  2576.016113  1911800
# 2003-12-24  3065.0  3270.0  2830.0  3000.0  2517.279297   666100
# 2003-12-26  3000.0  3140.0  2900.0  2900.0  2433.370117   342200
# 2003-12-29  2720.0  3030.0  2625.0  2800.0  2349.460693   707000

# %%
naver.head()
# Out:
#                     Open          High          Low         Close  \
# Date
# 2002-10-29   8988.620117   8988.620117  8988.620117   8988.620117
# 2002-10-30  10061.099609  10061.099609  9948.769531  10061.099609
# 2002-10-31  10214.299805  10459.500000  9325.700195   9560.629883
# 2002-11-01   9805.769531  10112.200195  8620.910156   8968.200195
# 2002-11-04   8886.480469   8947.769531  8304.259766   8518.759766
#
#               Adj Close   Volume
# Date
# 2002-10-29  8888.736328   100349
# 2002-10-30  9949.297852  4178437
# 2002-10-31  9454.389648  6465417
# 2002-11-01  8868.543945  3674734
# 2002-11-04  8424.097656  3387882

# %%
naver.to_csv('./naver.csv')

# %%
afreeca.to_pickle('./afreeca.pickle')
naver.to_excel('./naver.xls')

# %%
import pandas as pd

kosdaq = pd.read_pickle('./kosdaq.pickle')
kospi = pd.read_pickle('./kospi.pickle')

# %%
kosdaq.head()
# Out:
#    kor_name  ticker
# 0     제일홀딩스  003380
# 1  하나금융9호스팩  261200
# 2    교보7호스팩  267320
# 3      보라티알  250000
# 4    한화수성스팩  265920

# %%
kosdaq.tail()
# Out:
#        kor_name  ticker
# 1226     하이록코리아  013030
# 1227  SBI인베스트먼트  019550
# 1228      엠벤처투자  019590
# 1229      제미니투자  019570
# 1230        모헨즈  006920

# %%
def save_kosdaq():
    for stock in kosdaq.values:
        kor_name = stock[0]
        ticker = stock[1]
        df = data.get_data_yahoo(ticker + '.KQ', '1996-05-06', thread=20)
        df.to_csv('./kosdaq/{}.csv'.format(ticker))
        print('{}.csv is saved'.format(ticker))

def save_kospi():
    for stock in kospi.values:
        kor_name = stock[0]
        ticker = stock[1]
        df = data.get_data_yahoo(ticker + '.KS', '1996-05-06', thread=20)
        df.to_csv('./kospi/{}.csv'.format(ticker))
        print('{}.csv is saved'.format(ticker))

#save_kosdaq()
save_kospi()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# 003380.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 261200.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 267320.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 250000.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 265920.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 267980.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 225190.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 264850.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 161580.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 265480.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 256630.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 264290.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 166090.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 251370.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 258790.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 265520.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 263770.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 063760.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 264450.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 178320.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
#
.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 108320.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 079970.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 071200.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 100030.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 122690.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 900110.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 900100.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 115500.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 900120.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 115450.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 122350.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 115610.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 106080.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 115310.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 900090.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 101330.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 114570.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 115570.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 115440.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 050860.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 114630.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 080530.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 900070.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 099520.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 114450.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 104460.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 096640.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 112040.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 108860.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 900080.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 088290.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 114190.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 115160.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 109960.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 099410.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 101000.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 109820.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 082920.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 087220.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 042520.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 104200.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 052860.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 105330.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 109740.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 095700.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 108230.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 100130.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 103230.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 063080.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 109860.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 102120.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 101730.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 900040.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 102710.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 099440.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 102210.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 099220.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 101680.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 010240.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 099660.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 101170.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 081150.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 095300.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 098660.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 071670.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 101490.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 100120.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 102940.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 101400.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 106240.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 086890.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 104040.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 078070.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 086900.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 058630.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 059100.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 067630.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 092130.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 090730.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 100700.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 098120.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 083470.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 100090.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 101390.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 076080.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 101670.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 094840.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 063170.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 047560.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 096240.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 101160.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 099320.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 064480.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 098460.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 067000.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 018620.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 095610.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 053280.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 096870.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 059210.csv is saved
# ...
# 005990.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 034810.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 031390.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033430.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 025770.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033540.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033500.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 030350.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033310.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033160.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033320.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 009520.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 013810.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033340.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033200.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033290.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 015710.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033110.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033100.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033050.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 033130.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032980.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 019210.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 026150.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024660.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 031310.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032960.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032680.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032940.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 008290.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032750.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032860.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032850.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032790.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032800.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032620.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032580.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032540.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 028080.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032280.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 012340.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 031510.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 032040.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 030270.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 031860.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 031980.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 011560.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024740.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 030960.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 030530.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 026260.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 030520.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 021880.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 021040.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 029480.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 028040.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 028300.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 027710.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023600.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 018310.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 003800.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 014190.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 012700.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 018000.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 025980.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 026910.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 017250.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 015750.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 020180.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 006730.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 025950.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 025900.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 025870.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 025880.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 002680.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 025550.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 025440.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 025320.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024940.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024950.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 014100.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024840.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024910.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 004780.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 013120.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024830.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024810.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024880.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024120.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 017000.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 024060.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023910.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023890.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 001840.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023900.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 017650.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 010170.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023790.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023770.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023760.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 005860.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 012860.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023460.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 006050.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023430.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023410.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023440.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 006910.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 018290.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 023160.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 007530.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 001000.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 012620.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 011370.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 018700.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 014470.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 007720.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 006580.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 011320.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 018120.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 013720.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 009620.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 005670.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 007330.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 006140.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 019010.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 009780.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 017680.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 008800.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 020400.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 014200.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 005710.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 016600.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 004590.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 016670.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 000440.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 014970.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 011040.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 008370.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 007390.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 002290.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 019540.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 007770.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 017890.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 003310.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 019660.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 017510.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 021080.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 008830.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 002230.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 009730.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 016920.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 013030.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 019550.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 019590.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 019570.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# 006920.csv is saved
# [*********************100%***********************]  1 of 1 downloaded
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-b85653b0f50f> in <module>()
#      16
#      17 save_kosdaq()
# ---> 18 save_kospi()
#
# <ipython-input-28-b85653b0f50f> in save_kospi()
#      12         ticker = stock[1]
#      13         df = data.get_data_yahoo(ticker + '.KS', '1996-05-06', thread=20)
# ---> 14         df.to_csv('./kospi/{}.csv'.format(ticker))
#      15         print('{}.csv is saved'.format(ticker))
#      16
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# /usr/local/lib/python3.6/site-packages/pandas/io/formats/format.py in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
#    1638             close = True
#    1639
#
# /usr/local/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     388         elif encoding:
#     389             # Python 3 and encoding
# --> 390             f = open(path_or_buf, mode, encoding=encoding)
#     391         elif is_text:
#     392             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './kospi/268280.csv'

# %%
import re
import glob
from pandas_datareader import data

def reload_empty(market):
    file_list = glob.glob('./{}/*.csv'.format(market))
    six_digit = re.compile('\d{6}')
    for file_name in file_list:
        file = pd.read_csv(file_name)
        if file.empty:
            print("empty file {} is updated".format(file_name))
            ticker = six_digit.findall(file_name)[0]
            tmp_df = data.get_data_yahoo(ticker+'.KQ', start='1996-05-06', thread=20)
            tmp_df.to_csv(file_name)

reload_empty('kosdaq')
reload_empty('kospi')
